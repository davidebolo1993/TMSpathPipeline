# %% [markdown]
# # pars

# %%
import importlib
import tmspath_utils_rest as tmsr

importlib.reload(tmsr)

date,start_time=tmsr.import_modules()

json_data={
    # utils
    "date":date,
    "start_time":start_time,
    "analysis_id":None,
    "showPlotsEnd":False,
    "eeg_type":"rest",

    # filtering
    "do_filter_and_plot_raw":True,
    "r_sfreq":1024,
    "l_freq":0.1,
    "h_freq":45,
    "powerline_freq":50,
    "broad_band_h_freq":250,

    # cleaning
    "do_clean_trials_channels":True,
    "do_chan_trials_selection_automatic":True,
    "rest_auto_window_sec":1.0,
    "rest_auto_channel_z_threshold":3.5,
    "rest_auto_segment_z_threshold":3.5,
    "rest_auto_protect_seed_channels":True,
    "bad_trials":[],
    "bad_channels":[],
    
    #
    "do_rest_detrend" : True, # DC offset
    "rest_detrend_order" : 2, # se 0 è mean, come classico DC offset, se 1 è il trend lineare, se 2 non lineare di grado 2
    
    # porzioni nel continuo rimozione
    "rest_bad_segment_mode" : "free_annotations",
    "rest_annotation_h_freq_vis" : 60,
    "rest_gui_scaling" : 50e-6,
    "rest_crop_edges":False,
    "rest_preselect_edges_as_bad":True,
    "rest_crop_start_sec":30.0,
    "rest_crop_end_sec":30.0,
    
    # synthetic data
    "use_synthetic_rest_signal": False,
    "synthetic_rest_base_freq": 10.0,
    "synthetic_rest_jitter_hz": 5.0,
    "synthetic_rest_amplitude_uv": 20.0,
    "synthetic_rest_noise_uv": 5.0,
    "synthetic_rest_add_aperiodic": True,
    "synthetic_rest_aperiodic_exponent": 1.5,
    "synthetic_rest_aperiodic_amplitude_uv": 8.0,
    "synthetic_rest_aperiodic_fmin": 0.5,
    "synthetic_rest_seed": 42,
    "synthetic_rest_random_phase": True,
    "synthetic_rest_add_drift":True,
    "synthetic_rest_drift_type":"quadratic",
    "synthetic_rest_drift_amplitude_uv":100.0,
    
    # ICA: 
    "do_ica":True,
    'do_ica_continuum': False,
    'do_ica_manualCheck': True, 
    'do_ica_eigThresh': 0,
    'do_ica_automaticRej': False,
    'do_label_prob_threshold': 0,

    # directory and subject
    "mainDir":r"../data/PP064/",
    "sourceData":"MAYER",
    "subject":"PP064REST",
    "dataType":"ASCII",

    # tep path
    "tep_sx_file" : "PP064EMISFEROSX.EDF",
    "tep_dx_file" : "PP064EMISFERODX.EDF",
    "rest_tep_epoching" : True,
    "rest_tep_reject_by_annotation" : True,
    'epochs_timewindow_min': -0.1,
    'epochs_timewindow_max': 0.4,
    'baseline_cor_tmin': -0.15,
    'baseline_cor_tmax': 0,
    
}

# other
computeFOOOF = False

#
mainDir=json_data["mainDir"]
subject=json_data["subject"]
experiment_dir_=f"{mainDir}{subject}"
fileName=f"{mainDir}{subject}"
savePath=f"{mainDir}{subject}"
json_data["analysis_id"]=f"{date}_{subject}"

print(fileName)
# Out:
# ../data/PP064/PP064REST

# %% [markdown]
# # some ref
# - https://www.nature.com/articles/s41597-023-02525-0
# - https://www.jove.com/t/68350/pipemat-rs-development-validation-standardized-matlab-pipeline-for
# - https://www.frontiersin.org/journals/neuroscience/articles/10.3389/fnins.2018.00097/full
# - https://www.frontiersin.org/journals/neuroscience/articles/10.3389/fnins.2018.00513/full

# %% [markdown]
# # Resting-State EEG Processing Pipeline
#
# ### Loading & Filtering
#
# * **Load continuous resting-state EEG**
# * **Apply channel montage**
# * **Select EEG channels**
# * **Broad-band filter** (0.1–250 Hz)
# * **Notch filter** at 50 Hz and harmonics
#
# ---
#
# ### Artifact Detection
#
# * **Mark initial and final recording intervals as BAD**, or crop them
# * **Automatically detect bad channels**
# * **Automatically detect bad temporal segments**
# * **Manually review channels and annotations**
# * **Store bad channels** in `raw.info["bads"]`
#
# Bad channels are **not interpolated** at this stage.
#
# ---
#
# ### Continuous Detrending
#
# * *Optional:* **Polynomial detrending / DC correction**
# * Exclude BAD-annotated samples from the fit
# * Preserve all annotations and bad-channel labels
#
# ---
#
# ### Pre-ICA Spectral Analysis
#
# * **Compute Welch PSD**
# * **Extract frequency-band power**
#
#   * delta
#   * theta
#   * alpha
#   * beta
#   * gamma
# * *Optional:* **FOOOF aperiodic fitting and correction**
#
# ---
#
# ### ICA
#
# * **Downsample a copy for ICA**
# * **Apply average reference**
# * **Fit ICA on good EEG channels only**
# * Exclude BAD-annotated temporal intervals from ICA fitting
# * **Automatic and manual component selection**
#
#   * ICLabel
#   * topographies
#   * component PSDs
# * **Apply ICA correction to the continuous signal**
#
# ---
#
# ### Finalization
#
# * **Interpolate bad channels**
# * **Apply final average reference**
# * **Resample to the original sampling frequency**
# * **Compute post-ICA PSD and band power**
# * **Compare pre-ICA and post-ICA spectral measures**
# * **Save final Raw, ICA model, annotations, tables and plots**

# %% [markdown]
# # init

# %%
json_data, experiment_dir, sub = tmsr.directorySetup(json_data)
# Out:
# 📁 Generated experiment_dir: ../data/PP064/20260731102913_PP064REST

# %% [markdown]
# # load_and_prepare_raw_data

# %%
raw, events, json_data = tmsr.load_and_prepare_raw_data(
    json_data=json_data,
    fileName=fileName,
    experiment_dir=experiment_dir,
    sub=sub
)
# Out:
# 📌 Using provided experiment_dir: ../data/PP064/20260731102913_PP064REST
# GALNT ASCII CONVERTED FILE"
#
# Patient Data: " "PP064 PP064" "19/07/2010"
#
# Trace date: " "06/07/2026"
#
# Start second: " 0
#
# Seconds: " 235
#
# Sampling rate : " 4096
#
# Values are expressed in [uV]"
#
# TR 00", "TR 01", "TR 02", "TR 03", "TR 04", "TR 05", "TR 06", "TR 07", "TR 08", "TR 09", "TR 10", "TR 11", "TR 12", "TR 13", "TR 14", "TR 15", "TR 16", "TR 17", "TR 18", "TR 19", "TR 20", "TR 21", "TR 22", "TR 23", "TR 24", "TR 25", "TR 26", "TR 27", "TR 28", "TR 29", "TR 30", "TR 31", "TR 32"
#
# ['AF3', 'FC1', 'FC2', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'T3', 'C3', 'Cz', 'C4', 'T4', 'FC6', 'T5', 'P3', 'Pz', 'P4', 'T6', 'PO3', 'TP9', 'Oz', 'TP10', 'PO4', 'FPz', 'CP1', 'CP2', 'CP5', 'CP6', 'TM', 'MK']
# Il canale MK è presente nel DataFrame.
# Il canale EMG non è presente nel DataFrame.
# Il canale TM è presente nel DataFrame.
# Esperimento ha durata time=235.0 con sr=4096.0 e samples=962560
# Extracting EDF parameters from C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\PP064REST.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 962559  =      0.000 ...   235.000 secs...
# Il canale 'EMG' non è presente.
# ['AF3', 'FC1', 'FC2', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'T3', 'C3', 'Cz', 'C4', 'T4', 'FC6', 'T5', 'P3', 'Pz', 'P4', 'T6', 'PO3', 'TP9', 'Oz', 'TP10', 'PO4', 'Fpz', 'CP1', 'CP2', 'CP5', 'CP6', 'MK']
# TP9: [-0.0580141  -0.01885111 -0.034434  ]
# TP10: [ 0.05801216 -0.01885709 -0.034434  ]
# 📌 REST bordi preselezionati come BAD: inizio=30.000s, fine=30.000s
# 🧠 EEG REST: continuo puro
# [DEBUG] Saving layout to: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\1.basic\PP064REST_REST_continuum_scalplayout.png
# [DEBUG] Parent exists: True

# %% [markdown]
# # computeBasicSteps

# %%
raw_clean, json_data = tmsr.computeBasicSteps(
    raw,
    events,
    json_data,
    experiment_dir,
    sub,
    computeFOOOF=False
)
# Out:
# 🧠 [PP064REST] REST basic pipeline: raw continuum only + free annotations
# 🔧 [PP064REST] Step 1 REST: filtro continuo
# [DEBUG] filter_and_plot_raw out_dir: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\1.basic
# [DEBUG] filter_and_plot_raw parent exists: True
# DO-BROADBAND------------------------------------
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 2.5e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 12 (effective, after forward-backward)
# - Cutoffs at 0.10, 250.00 Hz: -6.02, -6.02 dB
#
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Setting 245760 of 962560 (25.53%) samples to NaN, retaining 716800 (74.47%) samples.
# Effective window size : 0.500 (s)
# At least one good data span is shorter than n_per_seg, and will be analyzed with a shorter window than the rest of the file.
# Plotting power spectral density (dB=True).
# DO-NOTCH------------------------------------
# NOTCH freqs: [50.0, 100.0, 150.0, 200.0]
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 27035 samples (6.600 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.0s
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Setting 245760 of 962560 (25.53%) samples to NaN, retaining 716800 (74.47%) samples.
# Effective window size : 0.500 (s)
# At least one good data span is shorter than n_per_seg, and will be analyzed with a shorter window than the rest of the file.
# Plotting power spectral density (dB=True).
# [INFO] Raw filtered and saved → C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\7.pkls\PP064REST_raw.pkl
# 🔧 [PP064REST] Step 2A REST: rilevamento automatico canali e finestre BAD
# 🤖 [PP064REST] REST automatic detection
#    Total duration: 235.000000 s
#    Initial excluded window: 30.000000 s
#    Final excluded window: 30.000000 s
#    Usable duration: 175.000000 s
#    Full windows: 175 × 1.000000 s
#    Final remainder: 0.000000 s
# Writing C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\2.trials\REST_auto_clean\PP064REST_raw_autoAnnotated.fif
# Closing C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\2.trials\REST_auto_clean\PP064REST_raw_autoAnnotated.fif
# [done]
# ✅ [PP064REST] REST automatic detection completed
#    Auto bad channels: ['AF4', 'Fpz']
#    Final bad channels: ['AF4', 'Fpz']
#    Auto bad windows: 0 / 175
#    Auto bad seconds: 0.000
#    Covered samples: 716800 / 716800
# 🔧 [PP064REST] Step 2B REST: revisione manuale delle annotazioni e dei canali
# 🖱️ [PP064REST] Manual free annotation of REST bad segments
#    Usa la GUI MNE per marcare porzioni BAD libere.
#    Premi 'a' se la modalità annotation non è già attiva.
#    Chiudi la finestra quando hai finito.
# 📌 BAD preselezionati: inizio=30.000s, fine=30.000s
#    BAD_REST_START era già presente.
#    BAD_REST_END era già presente.
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 60 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth lowpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 6 (effective, after forward-backward)
# - Cutoff at 60.00 Hz: -6.02 dB
#
# Using matplotlib as 2D backend.
# Channels marked as bad:
# ['AF4', 'Fpz']
# ✅ [PP064REST] Free annotations copied to raw
#    Total annotations: 2
#    BAD annotations:   2
#    BAD seconds:       60.00
#    Bad channels:      ['AF4', 'Fpz']
#    BAD_REST_START:   presente
#    BAD_REST_END:     presente
# Writing C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\2.trials\REST_free_annotations\PP064REST_raw_REST_freeAnnotated.fif
# Closing C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\2.trials\REST_free_annotations\PP064REST_raw_REST_freeAnnotated.fif
# [done]
# 🔧 [PP064REST] Step 3 REST: detrend polinomiale continuo / DC correction
# 🧼 [PP064REST] REST detrend continuo polinomiale, ordine=2
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Setting 245760 of 962560 (25.53%) samples to NaN, retaining 716800 (74.47%) samples.
# Effective window size : 0.500 (s)
# At least one good data span is shorter than n_per_seg, and will be analyzed with a shorter window than the rest of the file.
# Plotting power spectral density (dB=True).
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Setting 245760 of 962560 (25.53%) samples to NaN, retaining 716800 (74.47%) samples.
# Effective window size : 0.500 (s)
# At least one good data span is shorter than n_per_seg, and will be analyzed with a shorter window than the rest of the file.
# Plotting power spectral density (dB=True).
# ✅ [PP064REST] REST raw continuo detrendato salvato
# Writing C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\7.pkls\PP064REST_raw_REST_clean.fif
# Closing C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\7.pkls\PP064REST_raw_REST_clean.fif
# [done]
# ✅ [PP064REST] REST basic preprocessing completato
#    raw_clean:        <class 'mne.io.edf.edf.RawEDF'>
#    bad channels:     ['AF4', 'Fpz']
#    BAD annotations:  2
#    BAD seconds:      60.00
#    rest detrend:     True
#    detrend order:    2
#    fixed epochs:     False
#    5s segments:      False

# %%
print(raw_clean.annotations)
print(raw_clean.annotations.description)
print(raw_clean.annotations.onset[:10])
print(raw_clean.annotations.duration[:10])
sfreq=raw_clean.info["sfreq"]
import numpy as np
bad_mask=np.zeros(raw_clean.n_times,dtype=bool)

for ann in raw_clean.annotations:
    if str(ann["description"]).startswith("BAD"):
        start=int(round(ann["onset"]*sfreq))
        stop=int(round((ann["onset"]+ann["duration"])*sfreq))
        bad_mask[start:stop]=True

print("Bad samples:",bad_mask.sum())
print("Bad seconds:",bad_mask.sum()/sfreq)
print("Total seconds:",raw_clean.times[-1])
# Out:
# <Annotations | 2 segments: BAD_REST_END (1), BAD_REST_START (1)>
# ['BAD_REST_START' 'BAD_REST_END']
# [  0.       204.999756]
# [30. 30.]
# Bad samples: 245760
# Bad seconds: 60.0
# Total seconds: 234.999755859375

# %% [markdown]
# # ICAprocessing

# %%
(raw_clean_afterICA,
    postICA_final,
    postICA_raw_continuum,
    ica,
    json_data
)=tmsr.run_rest_ica(
    raw_clean=raw_clean,
    json_data=json_data,
    experiment_dir=experiment_dir,
    sub=sub
)
# Out:
# Bad channels esclusi da ICA: ['AF4', 'Fpz']
# Canali usati per ICA: 29
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Fitting ICA to data using 29 channels (please be patient, this may take a while)
# Omitting 61440 of 240640 (25.53%) samples, retaining 179200 (74.47%) samples.
# Selecting by number: 28 components
# Fitting ICA took 22.1s.
# <ICA | raw data decomposition, method: fastica (fit in 44 iterations on 179200 samples), 28 ICA components (29 PCA components available), channel types: eeg, no sources marked for exclusion>
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# 0 other 0.472295880317688
# 1 brain 0.890675961971283
# 2 eye blink 0.9545304775238037
# 3 brain 0.6999568343162537
# 4 brain 0.9950973987579346
# 5 brain 0.8385941982269287
# 6 eye blink 0.6117678284645081
# 7 brain 0.9958184361457825
# 8 eye blink 0.7096681594848633
# 9 other 0.696706235408783
# 10 muscle artifact 0.6305844783782959
# 11 muscle artifact 0.5434414148330688
# 12 brain 0.596473217010498
# 13 brain 0.7965410947799683
# 14 other 0.41457653045654297
# 15 brain 0.8376692533493042
# 16 brain 0.989852249622345
# 17 other 0.8349534273147583
# 18 brain 0.990027129650116
# 19 brain 0.7106475234031677
# 20 eye blink 0.35096603631973267
# 21 brain 0.9979318976402283
# 22 brain 0.9873731732368469
# 23 other 0.5113098621368408
# 24 brain 0.5101639032363892
# 25 brain 0.8545824289321899
# 26 other 0.6563429832458496
# 27 brain 0.9884510636329651
# Componenti artefattuali suggerite da ICLabel: [2, 6, 8, 10, 11, 20]
# ICLabel preselected: [2, 6, 8, 10, 11, 20]
# Topography selected: [2, 6, 8, 10, 11, 20]
# PSD selected: [2, 6, 8, 10, 11, 20]
# Combination mode: PSD_FINAL
# Final excluded: [2, 6, 8, 10, 11, 20]
# Kept: [0, 1, 3, 4, 5, 7, 9, 12, 13, 14, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 26, 27]
# Componenti selezionate da topografia: [2, 6, 8, 10, 11, 20]
# Componenti selezionate da PSD: [2, 6, 8, 10, 11, 20]
# Componenti finali escluse: [2, 6, 8, 10, 11, 20]
# Componenti tenute: [0, 1, 3, 4, 5, 7, 9, 12, 13, 14, 15, 16, 17, 18, 19, 21, 22, 23, 24, 25, 26, 27]
# Componenti finali escluse: [2, 6, 8, 10, 11, 20]
# Applying ICA to Raw instance
#     Transforming to ICA space (28 components)
#     Zeroing out 6 ICA components
#     Projecting back using 29 PCA components
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 86.5 mm
# Computing interpolation matrix from 29 sensor positions
# Interpolating 2 sensors
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Writing C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\7.pkls\20260731103157_PP064REST_postICA_final.fif
# Closing C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\7.pkls\20260731103157_PP064REST_postICA_final.fif
# [done]
# Salvato:
# C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\7.pkls\20260731103157_PP064REST_ica_model_continuum.pkl
# C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\7.pkls\20260731103157_PP064REST_postICA_raw_continuum.pkl
# C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\7.pkls\20260731103157_PP064REST_postICA_final.pkl
# Channels marked as bad:
# ['AF4', 'Fpz']
# Saving postICA outputs to: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\4.postICA\20260731103157
# Setting 61440 of 240640 (25.53%) samples to NaN, retaining 179200 (74.47%) samples.
# Effective window size : 2.000 (s)
# Plotting power spectral density (dB=True).
# Setting 61440 of 240640 (25.53%) samples to NaN, retaining 179200 (74.47%) samples.
# Effective window size : 2.000 (s)
# Plotting power spectral density (dB=True).
# Channels marked as bad:
# ['AF4', 'Fpz']
# Channels marked as bad:
# none
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated

# %% [markdown]
# # feature extraction postICA REST

# %%
json_data['rest_features_fmin'] = 1.0
json_data['rest_features_fmax'] = 40.0
json_data['rest_features_relative'] = True
json_data['rest_features_remove_aperiodic'] = True
json_data['pcist_baseline_window_ms'] = (-100, -10)
json_data['pcist_response_window_ms'] = (10, 300)

rest_feature_results, json_data = tmsr.extractRestFeatures(
    postICA_rest=raw_clean_afterICA,
    preICA_rest=raw_clean,
    json_data=json_data,
    experiment_dir=experiment_dir,
    sub=sub,
    compute_bands=True,
    compute_band_comparison=True,
    compute_null_pcist=True,
    pcist_module_name='tmspath_utils',
    tmin=-0.1,
    tmax=0.4,
    baseline=(-0.1, -0.01),
    pcist_baseline_window_ms=(-100, -10),
    pcist_response_window_ms=(10, 300),
    save=True
)

rest_feature_results
# Out:
# 🔧 REST features: PSD bands pre-ICA
# Saving PSD outputs to: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\PSDREST_preICA
# Setting 245760 of 962560 (25.53%) samples to NaN, retaining 716800 (74.47%) samples.
# Effective window size : 0.500 (s)
# At least one good data span is shorter than n_per_seg, and will be analyzed with a shorter window than the rest of the file.
# 🧮 Fit aperiodico per canale: 1.0-40.0 Hz, mode=fixed
# Plotting amplitude spectral density (dB=False).
# Plotting power spectral density (dB=True).
# ⚠️ PSD hdf5 non salvata: For HDF5-based I/O to work, the h5io module is needed, but it could not be imported.
#               use the following installation method appropriate for your environment:
#               'pip install h5io'
#               'conda install -c conda-forge h5io'
# ✅ PSD raw + aperiodic-corrected REST_preICA salvate in: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\PSDREST_preICA
# 🔧 REST features: PSD bands post-ICA
# Saving PSD outputs to: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\PSDREST_postICA
# Setting 245760 of 962560 (25.53%) samples to NaN, retaining 716800 (74.47%) samples.
# Effective window size : 0.500 (s)
# At least one good data span is shorter than n_per_seg, and will be analyzed with a shorter window than the rest of the file.
# 🧮 Fit aperiodico per canale: 1.0-40.0 Hz, mode=fixed
# Plotting amplitude spectral density (dB=False).
# Plotting power spectral density (dB=True).
# ⚠️ PSD hdf5 non salvata: For HDF5-based I/O to work, the h5io module is needed, but it could not be imported.
#               use the following installation method appropriate for your environment:
#               'pip install h5io'
#               'conda install -c conda-forge h5io'
# ✅ PSD raw + aperiodic-corrected REST_postICA salvate in: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\PSDREST_postICA
# 🔧 REST features: confronto bande pre/post ICA
# Saving bandpower comparison to: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\BP_REST_preICA_raw_REST_postICA_raw
# out_dir exists: True
# Path length: 205
# ✅ Confronto PSD bands salvato in: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\BP_REST_preICA_raw_REST_postICA_raw
# Saving bandpower comparison to: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\BP_REST_preICA_APcorr_REST_postICA_APcorr
# out_dir exists: True
# Path length: 211
# ✅ Confronto PSD bands salvato in: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\BP_REST_preICA_APcorr_REST_postICA_APcorr
# 🔧 REST features: epoching on TEP SX/DX trigger times
# TEP SX: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\PP064EMISFEROSX.EDF
# TEP DX: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\PP064EMISFERODX.EDF
# Not setting metadata
# 127 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 127 events and 2049 original time points ...
# 30 bad epochs dropped
# Not setting metadata
# 128 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 128 events and 2049 original time points ...
# 29 bad epochs dropped
# ✅ REST TEP SX: 97 epoche
# ✅ REST TEP DX: 99 epoche
# Finestra: -0.1 → 0.4 s
# Baseline: (-0.1, -0.01)
# Risultati: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\REST_features_TEP_epoching
# 🔧 REST features: null/control PCIst SX and DX
# ✅ PCIst = 14.301 | retained dimensions = 2
# ✅ PCIst = 33.813 | retained dimensions = 4
# ✅ REST feature extraction completata: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731102913_PP064REST\5.Extra\FE\REST
# {'subject': 'PP064REST',
#  'analysis_type': 'REST_postICA_features',
#  'feature_directory': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\REST",
#  'null_pcist_interpretation': 'PCIst computed on resting-state epochs aligned to TEP trigger times. This is a null/control complexity estimate, not an evoked perturbational PCI.',
#  'bands': {'preICA_computed': True,
#   'postICA_computed': True,
#   'postICA_raw_csv': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\PSDREST_postICA\\raw\\PP064REST_REST_postICA_bandpower_raw_wide.csv",
#   'postICA_apec_csv': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\PSDREST_postICA\\apec\\PP064REST_REST_postICA_bandpower_corrected_wide.csv",
#   'postICA_aperiodic_csv': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\PSDREST_postICA\\PP064REST_REST_postICA_aperiodic_parameters.csv"},
#  'band_comparison': {'raw_summary': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\BP_REST_preICA_raw_REST_postICA_raw\\summary.csv",
#   'apec_summary': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\BP_REST_preICA_APcorr_REST_postICA_APcorr\\summary.csv"},
#  'tep_trigger_epoching': {'sx_epochs': 97,
#   'dx_epochs': 99,
#   'mapping_csv': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\REST_features_TEP_epoching\\PP064REST_REST_TEP_event_mapping.csv",
#   'tmin': -0.1,
#   'tmax': 0.4,
#   'baseline': (-0.1, -0.01)},
#  'null_pcist': {'SX': {'value': 14.301467180229823,
#    'n_dims': 2,
#    'dNST': [11.498824853732648, 2.802642326497175],
#    'output_directory': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\PCIst",
#    'label': 'REST null/control PCIst'},
#   'DX': {'value': 33.81316115748002,
#    'n_dims': 4,
#    'dNST': [3.0169279549410426,
#     14.363303569103689,
#     10.99517653232704,
#     5.437753101108246],
#    'output_directory': "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731102913_PP064REST\\5.Extra\\FE\\PCIst",
#    'label': 'REST null/control PCIst'}}}

# %% [markdown]
# # save and loading

# %%
json_data = tmsr.saveLoadTestFinal(
    raw_clean_afterICA,
    json_data,
    experiment_dir,
    sub,
    start_time
)
