# %% [markdown]
# # pars

# %%
from pathlib import Path
import importlib
import tmspath_utils as tmsu
importlib.reload(tmsu)
date,start_time=tmsu.import_modules()

# %%
detrendType="Windowed"

if detrendType=="Non-Windowed":
    typeOffsetRise="nowind_biexp"
    typeOffsetDecay="nowind_biexp"
elif detrendType=="Windowed":
    typeOffsetRise="wind_poly_lagrange"
    typeOffsetDecay="wind_poly_3"
elif detrendType=="ICA_Detrend":
    typeOffsetRise="ICA"
    typeOffsetDecay="ICA"
else:
    raise ValueError(
        "detrendType deve essere "
        "'Windowed', 'Non-Windowed' oppure 'ICA_Detrend'"
    )

json_data={
    # utils
    "date":date,
    "start_time":start_time,
    "do_filter_and_plot_raw":True,
    "showPlotsEnd":False,
    "r_sfreq":1024,
    "eeg_type":"tep",
    
    # filtering
    "l_freq":0.1,
    "h_freq":45,
    "powerline_freq":50,
    "broad_band_h_freq":250,

    # stimulation
    "do_pulseArtifactRej":True,
    "pulse_artifact_rej_timewindow_min":-0.002,
    "pulse_artifact_rej_timewindow_max":0.008,
    "emispheric_stimulation":"DX",

    # epoching
    "do_prepare_epochs":True,
    "epochs_timewindow_min":-0.1,
    "epochs_timewindow_max":0.4,
    "baseline_cor_tmin":-0.1,
    "baseline_cor_tmax":0.0,

    # channels and trials cleaning
    "do_clean_trials_channels":True,
    "do_chan_trials_selection_automatic":True,
    "bad_trials":[],
    "bad_channels":[],

    # injected artifacts
    "do_artifact":False,
    "do_artifact_rise":0.005,
    "do_artifact_decay":0.1,
    "do_artifact_gain":-3e-6*30,
    "do_artifact_chans":["Cz"],

    # ICA
    "do_ica":True,
    "do_ica_continuum":False,
    "do_ica_manualCheck":False,
    "do_ica_eigThresh":0,
    "do_ica_automaticRej":False if detrendType=="ICA_Detrend" else True,
    "do_label_prob_threshold":0,

    # detrend
    "trials_wise":True,
    "detrendExtremeTechinque":"max",
    "detrend_type":typeOffsetDecay,
    "do_detrend":typeOffsetDecay!="ICA",
    "do_detrend_onlyOffsetChans":False,
    "detrend_offsetStart":True,
    "detrend_lag_correction":False,
    "detrend_typeOffsetRise":typeOffsetRise,
    "detrend_typeOffsetDecay":typeOffsetDecay,
    "detrend_polOrder_preOffset":2,
    "detrend_slopeThr":0.5,
    "detrend_offsetCorrectionType":"Gaussian" if "nowind" not in typeOffsetDecay else False,
    "detrend_offsetOddSamples":5,
    "detrend_overall":True,
    "detrend_noWindowedOrder":1,
    "detrend_maxTimeWindowOffset":0.020,
    "detrend_minTimeWindowOffset":0.0,
    "detrend_fitConstraint":False if "nowind" not in typeOffsetDecay else True,

    # standard features
    "do_standard_features":True,
    "do_fooof_features":False,

    # temporal fingerprint
    "do_tep_fingerprint":True,
    "tep_fingerprint_ntop":4,
    "tep_fingerprint_p1_window_ms":(10,40),
    "tep_fingerprint_search_end_ms":200,
    "tep_fingerprint_min_peak_distance_ms":14,
    "tep_fingerprint_baseline_s":(-0.1,-0.01),
    "tep_fingerprint_min_roi_fraction":0.30,
    "tep_fingerprint_exclude_channels":[
        "Fp1","Fpz","Fp2","F7","F8",
        "FT7","FT8","T7","T8",
        "TP7","TP8","TP9","TP10",
        "P7","P8","Iz"
    ],

    # natural frequency
    "do_tep_natural_frequency":True,
    "tep_nf_fmin":4.0,
    "tep_nf_fmax":45.0,
    "tep_nf_stockwell_width":0.7,
    "tep_nf_baseline_window_ms":(-100,-10),
    "tep_nf_response_window_ms":(20,120),

    # PCIst
    "do_pcist":True,
    "pcist_baseline_window_ms":(-100,-10),
    "pcist_response_window_ms":(10,300),
    "pcist_k":1.2,
    "pcist_min_snr":1.1,
    "pcist_max_var":99,
    "pcist_embed":False,
    "pcist_n_steps":100,
    "pcist_baseline_corr":False,

    # directory and subject
    "mainDir":r"C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data",
    "sourceData":"MAYER",
    "subject":"PP064",
    "dataType":"ASCII"
}

json_data,experiment_dir,sub,fileName,savePath=tmsu.setup_tep_analysis(json_data)

do_run_features=True
# Out:
# 📁 Generated TEP experiment_dir: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX
# Subject: PP064
# Hemisphere: DX
# Seed channels: ['Fz', 'AF4', 'F4', 'FC2']
# Subject directory: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064
# Subject directory exists: True
# Input stem: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\PP064EMISFERODX
# Output directory: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX
# Analysis ID: 20260731160833_PP064DX

# %% [markdown]
# # TMS-EEG Processing Pipeline
#
# ### 1. Preprocessing & Artifact Removal
# 1. **Load EEG**
# 2. **Apply montage**
# 3. **Detect TMS events**
# 4. **Remove TMS pulse artifact**
# 5. **Broad-band filter** (0.1–250 Hz)
# 6. **Notch filter** (50 / 100 / 150 / 200 / 250 Hz)
#
# ---
#
# ### 2. Preliminary Cleaning
# 7. **Create long temporary epochs** (for visual/automatic cleaning)
# 8. **Automatic / manual trial and channel inspection**
# 9. **Reject bad trials**
# 10. **Mark bad channels** in `info["bads"]`
#    Bad channels are **not dropped** at this stage.
#
# ---
#
# ### 3. Epoching & Detrending
# 11. **Create final epochs** (-100 to +400 ms) using only retained trials
# 12. **Preserve all EEG channels**
# 13. **Propagate bad-channel labels** to final epochs
# 14. **Downsample** to processing rate, e.g. 1024 Hz
# 15. **Average reference** using good channels only
# 16. *Optional:* **Pre-detrend PSD / FOOOF**
# 17. **Slope and offset analysis**
# 18. **Selected detrending strategy**
#
# ---
#
# ### 4. ICA
# 19. **Prepare ICA copy**
#     - bad channels remain in the full data object
#     - ICA fitting uses only EEG channels not marked as bad
#
# 20. **Fit ICA on good channels only**
#
# 21. **Automatic / manual ICA component selection**
#     - ICLabel / eigenvalue criteria if enabled
#     - manual component inspection if enabled
#
# 22. **Apply ICA correction** to the full epoched object
#
# ---
#
# ### 5. Finalizing
# 23. **Final filter** (0.1–45 Hz)
# 24. **Resample** to original sampling rate
# 25. **Interpolate bad channels**
# 26. **Final average reference**
# 27. **Save** `postICA_final` and final plots
#
# ---
#
# ### 6. Features Extraction
# 28. **to-add**
# 29. **to-add**
# 30. **to-add**

# %% [markdown]
# # init

# %%
json_data,experiment_dir,sub=tmsu.directorySetup(json_data)
# Out:
# 📌 Using provided experiment_dir: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX

# %%
experiment_dir
# Out:
# "C:\\Users\\verga\\OneDrive - Scuola Superiore Sant'Anna\\dellXXX-home-Pontedera\\Documenti\\MAIN\\073_tempTMSpath\\TMSpathPipeline\\data\\PP064\\20260731160833_PP064DX"

# %% [markdown]
# # load_and_prepare_raw_data

# %%
raw,events,json_data=tmsu.load_and_prepare_raw_data(
    fileName=fileName,
    json_data=json_data,
    experiment_dir=experiment_dir,
    sub=sub
)
# Out:
# 📌 Using provided experiment_dir: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX
# GALNT ASCII CONVERTED FILE"
#
# Patient Data: " "PP064 PP064" "19/07/2010"
#
# Trace date: " "06/07/2026"
#
# Start second: " 0
#
# Seconds: " 273
#
# Sampling rate : " 4096
#
# Values are expressed in [uV]"
#
# TR 00", "TR 01", "TR 02", "TR 03", "TR 04", "TR 05", "TR 06", "TR 07", "TR 08", "TR 09", "TR 10", "TR 11", "TR 12", "TR 13", "TR 14", "TR 15", "TR 16", "TR 17", "TR 18", "TR 19", "TR 20", "TR 21", "TR 22", "TR 23", "TR 24", "TR 25", "TR 26", "TR 27", "TR 28", "TR 29", "TR 30", "TR 31", "TR 32"
#
# ['AF3', 'FC1', 'FC2', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'T3', 'C3', 'Cz', 'C4', 'T4', 'FC6', 'T5', 'P3', 'Pz', 'P4', 'T6', 'PO3', 'TP9', 'Oz', 'TP10', 'PO4', 'FPz', 'CP1', 'CP2', 'CP5', 'CP6', 'TM', 'MK']
# Il canale MK è presente nel DataFrame.
# Il canale EMG non è presente nel DataFrame.
# Il canale TM è presente nel DataFrame.
# Esperimento ha durata time=273.0 con sr=4096.0 e samples=1118208
# Extracting EDF parameters from C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\PP064EMISFERODX.EDF...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1118207  =      0.000 ...   273.000 secs...
# Il canale 'EMG' non è presente.
# ['AF3', 'FC1', 'FC2', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'T3', 'C3', 'Cz', 'C4', 'T4', 'FC6', 'T5', 'P3', 'Pz', 'P4', 'T6', 'PO3', 'TP9', 'Oz', 'TP10', 'PO4', 'Fpz', 'CP1', 'CP2', 'CP5', 'CP6', 'MK']

# %% [markdown]
# # computeBasicSteps

# %%
raw_cleaned,epochs,detrendedEpochs,temp_epochs,json_data=tmsu.computeBasicSteps(
    raw,
    events,
    json_data,
    experiment_dir,
    sub,
    computeFOOOF=False
)
# Out:
# 🔧 [PP064] Step 1: Rimozione artefatto TMS + PSD
# 📉 Plotting PSD before pulse removal...
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# ⚡ Removing TMS pulse artifact...
# 📉 Plotting PSD after pulse removal...
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# 🔧 [PP064] Step 2: Filtro broad-band e notch
# DO-BROADBAND------------------------------------
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 2.5e+02 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 12 (effective, after forward-backward)
# - Cutoffs at 0.10, 250.00 Hz: -6.02, -6.02 dB
#
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# DO-NOTCH------------------------------------
# DO-NOTCH------------------------------------
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 27035 samples (6.600 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.7s
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# [INFO] Raw filtered and saved → C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX\6.pkls\PP064_raw.pkl
# 🔧 [PP064] Step 3: Pulizia epoche e canali artefattati
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.1 - 45 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 12 (effective, after forward-backward)
# - Cutoffs at 0.10, 45.00 Hz: -6.02, -6.02 dB
#
# Not setting metadata
# 150 matching events found
# Setting baseline interval to [-0.800048828125, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 150 events and 36046 original time points ...
# 2 bad epochs dropped
# 🤖 Automatic artifact rejection
# 🧹 Dropping automatic bad trials: [0, 27, 29, 30, 88, 89, 91, 92, 101, 141, 142, 143, 144, 145, 146, 147]
# 📌 Marking automatic bad channels, not dropping: ['CP2', 'Fpz', 'TP10']
# ✅ clean_trials_channels completed
#    Trials kept: 132 / 148
#    Channels kept in object: 31 / 31
#    Marked bad channels: ['CP2', 'Fpz', 'TP10']
#    Dropped channels: none
# 🔧 [PP064] Step 4: Creazione oggetto Epochs finale
# Not setting metadata
# 150 matching events found
# Setting baseline interval to [-0.10009765625, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 150 events and 2049 original time points ...
# 0 bad epochs dropped
# 📌 Marking bad channels in final epochs, not dropping: ['CP2', 'Fpz', 'TP10']
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# Averaging across epochs...
# ✅ prepare_epochs completed
#    Final trials: 132
#    Final channels: 31
#    Final channel names: ['AF3', 'FC1', 'FC2', 'AF4', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'T3', 'C3', 'Cz', 'C4', 'T4', 'FC6', 'T5', 'P3', 'Pz', 'P4', 'T6', 'PO3', 'TP9', 'Oz', 'TP10', 'PO4', 'Fpz', 'CP1', 'CP2', 'CP5', 'CP6']
# ✅ [PP064] Completato. Informazioni finali su Epochs:
# <Info | 11 non-empty values
#  bads: 3 items (CP2, Fpz, TP10)
#  ch_names: AF3, FC1, FC2, AF4, F7, F3, Fz, F4, F8, FC5, T3, C3, Cz, C4, T4, ...
#  chs: 31 EEG
#  custom_ref_applied: True
#  dig: 34 items (3 Cardinal, 31 EEG)
#  highpass: 1.6 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2026-07-06 18:43:32 UTC
#  nchan: 31
#  projs: []
#  sfreq: 1024.0 Hz
#  subject_info: 4 items (dict)
# >
#
# 🔍 [PP064] Step 1: Verifica della necessità di detrending...
#
# 🔍 [PP064] Step 1: analisi delle latenze offset
# Processing channels: 100%|█████████████████████████████████████████████████████████████| 31/31 [00:02<00:00, 15.15it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:45<00:00,  1.48s/it]
# 📉 [PP064] Step 2: Calcolo delle pendenze (computeSlopes_v4)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:11<00:00,  2.79it/s]
# 📊 [PP064] Step 3: Plot delle pendenze normalizzate (Zslope)
# p_value nan F nan
# 📈 [PP064] Step 4: Calcolo media Zslope per canale e finestra
#
# 📌 [PP064] Risultati:
#    • Zslope threshold = 0.5
#    • Canali oltre soglia (5): ['AF4', 'F4', 'FC2', 'Fpz', 'Fz']
#    • do_detrend = True
#
# 🧼 [PP064] Step 2: Esecuzione del pipeline di detrending sui canali selezionati...
# --- Mode: TRIALS-WISE (Processing all individual trials) ---
# epochs_to_process data shape: (132, 31, 512)
# epochs_to_process times len: 512
# I am doing wind_poly_3 detrend
# ###
# 660
# p plot 0.015151515151515152
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [01:01<00:00,  1.98s/it]
# INPUT data shape: (132, 31, 512)
# INPUT times len: 512
# DETRENDED data shape: (132, 31, 512)
# DETRENDED times len: 512
# [INFO] Salvato tabStat in: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX\2.detrend\tabStatDetrend_wind_poly_3.csv
# 100%|██████████████████████████████████████████████████████████████████████████████████| 31/31 [00:12<00:00,  2.57it/s]
# p_value nan F nan
# 🔧 Applico notch IIR a canali offset ['AF4', 'F4', 'FC2', 'Fpz', 'Fz'] su frequenze: [50, 100, 150, 200, 250]
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.1s
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.0s
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.1s
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.1s
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 1.00 Hz
# - Upper transition bandwidth: 1.00 Hz
# - Filter length: 3381 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    0.2s
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# Averaging across epochs...
# ✅ [PP064] Detrending completato.
#
#
# 🔍 [PP064] Step 3: Compute FOOOF

# %% [markdown]
# # ICAprocessing

# %%
if json_data["do_ica"]:
    dataToICA=detrendedEpochs if json_data["detrend_overall"] else epochs

    postICA_final,json_data=tmsu.ICAprocessing(
        dataToICA,
        json_data,
        experiment_dir,
        sub,
        autoReject=json_data["do_ica_automaticRej"],
        manualCheck=json_data["do_ica_manualCheck"],
        computeFOOOF=False
    )

    do_run_gif=True

    if do_run_gif:
        from pathlib import Path
        
        postica_subpath=Path("4.postICA")/json_data["ICA_timestamp"]

        gif_path,json_data=tmsu.create_butterfly_topomap_gif(
            epochs=postICA_final,
            json_data=json_data,
            experiment_dir=experiment_dir,
            sub=sub,
            saveNote="postICA_final",
            subPath=str(postica_subpath),
            tmin=-0.1,
            tmax=0.45,
            step=0.002,
            xlim=(-0.1,0.45),
            vlim=(-5,5),
            sphere=0.095,
            duration=50,
            transparency=False,
            save_static=True
        )



        print(gif_path)
# Out:
# ⚙️ ICA eigThresh = 0, label_prob_threshold = 0
# [INFO] Oggetto passato direttamente
# 📌 Bad channels marked before ICA: ['CP2', 'Fpz', 'TP10']
# 🧠 ICA fit on good channels only: 28 channels
# 🧠 ICA n_components: 27
# Fitting ICA to data using 28 channels (please be patient, this may take a while)
# Selecting by number: 27 components
# Fitting ICA took 9.1s.
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# ✅ IC 0: brain (prob: 1.00) – mantenuto automaticamente
# ✅ IC 1: brain (prob: 0.88) – mantenuto automaticamente
# ✅ IC 2: brain (prob: 0.99) – mantenuto automaticamente
# ✅ IC 3: brain (prob: 0.98) – mantenuto automaticamente
# ✅ IC 4: brain (prob: 0.82) – mantenuto automaticamente
# ✅ IC 5: brain (prob: 1.00) – mantenuto automaticamente
# ❌ IC 6: muscle artifact (prob: 0.91) – escluso automaticamente
# ✅ IC 7: brain (prob: 1.00) – mantenuto automaticamente
# ❌ IC 8: muscle artifact (prob: 0.76) – escluso automaticamente
# ✅ IC 9: brain (prob: 0.93) – mantenuto automaticamente
# ✅ IC 10: brain (prob: 0.67) – mantenuto automaticamente
# ✅ IC 11: brain (prob: 0.56) – mantenuto automaticamente
# ❌ IC 12: muscle artifact (prob: 0.78) – escluso automaticamente
# ❌ IC 13: other (prob: 0.48) – escluso automaticamente
# ❌ IC 14: muscle artifact (prob: 0.85) – escluso automaticamente
# ✅ IC 15: brain (prob: 0.78) – mantenuto automaticamente
# ❌ IC 16: muscle artifact (prob: 0.77) – escluso automaticamente
# ❌ IC 17: other (prob: 0.35) – escluso automaticamente
# ❌ IC 18: other (prob: 0.77) – escluso automaticamente
# ❌ IC 19: muscle artifact (prob: 0.95) – escluso automaticamente
# ✅ IC 20: brain (prob: 0.70) – mantenuto automaticamente
# ✅ IC 21: brain (prob: 0.77) – mantenuto automaticamente
# ✅ IC 22: brain (prob: 0.97) – mantenuto automaticamente
# ✅ IC 23: brain (prob: 0.45) – mantenuto automaticamente
# ❌ IC 24: heart beat (prob: 0.72) – escluso automaticamente
# ✅ IC 25: brain (prob: 0.49) – mantenuto automaticamente
# ✅ IC 26: brain (prob: 0.75) – mantenuto automaticamente
# [Auto-tagging] Componenti escluse per ICLabel: [6, 8, 12, 13, 14, 16, 17, 18, 19, 24]
# [Autovalori] Componenti escluse eigenvalue <= 0.0374: [26]
# 📌 ICA initial excluded: [6, 8, 12, 13, 14, 16, 17, 18, 19, 24, 26]
# 📌 ICA final excluded:   [6, 8, 12, 13, 14, 16, 17, 18, 19, 24, 26]
# 📌 ICA manual added:     []
# 📌 ICA manual recovered: []
# Applying ICA to Epochs instance
#     Transforming to ICA space (27 components)
#     Zeroing out 11 ICA components
#     Projecting back using 28 PCA components
# Setting up band-pass filter from 0.1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.10
# - Lower transition bandwidth: 0.10 Hz (-6 dB cutoff frequency: 0.05 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 33793 samples (33.001 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=1)]: Done 647 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=1)]: Done 881 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=1)]: Done 1151 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=1)]: Done 1457 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=1)]: Done 1799 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=1)]: Done 2177 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=1)]: Done 2591 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=1)]: Done 3041 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=1)]: Done 3527 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=1)]: Done 4049 tasks      | elapsed:   12.8s
# 🧩 Interpolating bad channels after ICA: ['CP2', 'Fpz', 'TP10']
# Setting channel interpolation method to {'eeg': 'spline'}.
# Interpolating bad channels.
#     Automatic origin fit: head of radius 86.5 mm
# Computing interpolation matrix from 28 sensor positions
# Interpolating 3 sensors
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.500 (s)
# Plotting power spectral density (dB=True).
# Averaging across epochs...
# 2026-07-31 16:16:16,967 - matplotlib.animation - WARNING - MovieWriter ffmpeg unavailable; using Pillow instead.
# 2026-07-31 16:16:16,970 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.PillowWriter'>
# Video salvato in: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX\4.postICA\20260731161513/PP064_scalpmaptime_postICA.gif
# ✅ GIF salvata: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX\4.postICA\20260731161513\PP064_postICA_final_butterfly_topomap_opaque.gif
# C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX\4.postICA\20260731161513\PP064_postICA_final_butterfly_topomap_opaque.gif

# %% [markdown]
# # feature extraction postICA

# %%
if do_run_features:        
    feature_results,json_data=tmsu.extractFeatures(
        postICA_final=postICA_final,
        json_data=json_data,
        experiment_dir=experiment_dir,
        sub=sub,
    )
# Out:
# 🔧 Feature extraction: standard post-ICA features
#
# FOOOF WARNING: Skipping frequency == 0, as this causes a problem with fitting.
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 32.00
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# 🔧 Feature extraction: PCIst
# ✅ PCIst = 62.954 | retained dimensions = 7
# 📚 PCIst reference: Comolatti R et al., Brain Stimulation, 2019;12(5):1280-1289. doi:10.1016/j.brs.2019.05.013
# 💻 PCIst software: https://github.com/renzocom/PCIst
# 🔧 Feature extraction: TEP temporal fingerprint
# Could not find a adjacency matrix for the data. Computing adjacency based on Delaunay triangulations.
# -- number of adjacent vertices : 31
# ✅ TEP temporal fingerprint completato
#    Subject: PP064
#    Seed channel: F4
#    ROI channels: ['F4', 'AF4', 'Fz', 'FC2']
#    ROI size: 4 / 4 richiesta
#    LP1: 22.461 ms
#    LP2: 38.757 ms
#    LP3: 69.214 ms
#    AP1-P2: 7.768 µV
#    AP2-P3: 6.577 µV
#    |SP1-P2|: 0.477 µV/ms
#    |SP2-P3|: 0.229 µV/ms
#    IPI: 46.753 ms
#    IPIHz: 22.585 Hz
# 📚 Reference: Hassan G, Gaglioti G, Furregoni G, et al. Temporal fingerprints of TMS-evoked potentials across thalamocortical circuits. bioRxiv, 2026.
# 🔗 DOI: 10.64898/2026.06.29.734769
#    Results: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX\5.Extra\FE\Fingerprint
# ✅ Feature extraction completata: C:\Users\verga\OneDrive - Scuola Superiore Sant'Anna\dellXXX-home-Pontedera\Documenti\MAIN\073_tempTMSpath\TMSpathPipeline\data\PP064\20260731160833_PP064DX\5.Extra\FE
#    Sections: ['standard', 'PCIst', 'TEP_fingerprint']

# %% [markdown]
# # save and load

# %%
json_data=tmsu.saveLoadTestFinal(
    postICA_final,
    json_data,
    experiment_dir,
    sub,
    start_time
)
# Out:
# QFileDialog
# make_standard_montage
# label_components
# PrepPipeline
# NoisyChannels
# datetime
# euclidean
# Path
# interp1d
# resample
# expon
# gamma
# laplace
# linregress
# norm
# poisson
# rayleigh
# t
# uniform
# ARIMA
# FuncAnimation
# tabulate
# tqdm
# notebook_tqdm
# create_info
# EvokedArray
# RawArray
# FOOOF
# gen_power_spectrum
# set_random_seed
# plot_spectra
# plot_annotated_model
# import_modules
# make_json_serializable
# directorySetup
# load_pipeline_version
# directorySetup_old_20260416
# loadEDF
# loadASCII
# computeDetrendSteps
# add_exp_artifact
# computeBasicSteps
# load_and_prepare_raw_data
# run_ica_continuum_pipeline
# remove_tms_artifact_and_plot_psd
# filter_and_plot_raw
# clean_trials_channels
# clean_trials_channels_20072026
# clean_trials_channels_old_20260416
# clean_trials_channels_20260415
# apply_notch_to_offsetChans
# run_detrend_pipeline
# notch_filter_offset_chans
# apply_notch_filter
# prepare_epochs
# analyze_offset_times
# check_detrend_need
# add_TEP_to_json
# compute_pcist
# ICAprocessing
# ICAprocessing_old_20260416
# extractFeatures
# computeFeatExtraction
# computeFeatExtraction_v2
# plot_TEP_1d_with_shading
# saveLoadTestFinal
# saveLoadTestFinal_old_20260416
# selectTEPfeat
# set_plot_params
# FIGSIZE
# shift_signal_by_mask
# polyfit_constrained_start
# compute_condition_number_epochs_average
# run_ica_filtering_v3
# run_ica_filtering_v3_20072026
# run_ica_filtering_v3_old_20260416
# postICAsteps
# plot_ersp
# plot_topomap
# plot_gmfp
# find_outlier_channels_by_twindow_v2
# find_outlier_channels_by_twindow
# find_outlier_channels_by_twindow_v3
# run_ica_filtering
# run_ica_filtering_v2
# run_ica_artist_ext_only
# run_ica_artist_tms_events
# plot_customTEP
# basicPlots
# create_butterfly_topomap_gif
# runICA
# welch
# filter_data
# extract_psd_features
# save_bad_epochs_and_channels
# plotTrialTepVariability
# computeTimeMasks
# computeTimeMasks_old16102025
# computeTimeMasks_old15102025
# computeTimeMasks_old
# computeSlopes_v4
# computeSlopes_v4_old
# computeSlopesPlot_v3
# computeSlopesPlot_v2
# computeSlopesPlot
# generate_noise_from_distribution
# generate_noise_from_distribution_old151012025
# supported_models
# computeDetrend_v6
# plot_detrend_example_v3
# plot_detrend_example
# plot_tabStat
# apply_offset_correction
# apply_offset_correction_old15102025
# plot_slope_resonances
# init_notes
# log_note
# start_log_step
# end_log_step
# finalize_notes
# compute_tep_natural_frequency
# compute_tep_fingerprint
# ✅ Tempo totale di esecuzione: 728.20 secondi
